# %% [markdown]
# <a href="https://colab.research.google.com/github/Jellyjellyjinjin/Daycon-car-object-detection-/blob/main/yolov5m.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import os
import cv2
from tqdm import tqdm
import shutil
import math

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
txt_file_list = glob.glob('/content/drive/MyDrive/pretrain/*.txt')

# %%
for file in tqdm(txt_file_list):
    file_name = os.path.basename(file)
    file_name = file_name.split('.')[0]
    img = cv2.imread('/content/drive/MyDrive/pretrain/' + file_name + '.png')
    img_height, img_width, _ = img.shape
    print(file_name, img_height, img_width)
    cv2.destroyAllWindows()
    with open(file, 'r') as f:
        lines_list = []
        lines = f.readlines()
        for line in lines:
            line = list(map(float, line.strip().split(' ')))
            class_name = int(line[0])
            x_min, y_min = float(min(line[5], line[7])), float(min(line[6], line[8]))
            x_max, y_max = float(max(line[1], line[3])), float(max(line[2], line[4]))
            x_center, y_center = float(((x_min + x_max) / 2) / img_width), float(((y_min + y_max) / 2) / img_height)
            width, height = abs(x_max - x_min) / img_width, abs(y_max - y_min) / img_height
            print(x_center, y_center, width, height)
            lines_list.append([class_name, x_center, y_center, width, height])
    with open('/content/drive/MyDrive/pretrain/labels/' + file_name + '.txt', 'w') as f:
        for line in lines_list:
            f.write(str(line[0]) + ' ' + str(line[1]) + ' ' + str(line[2]) + ' ' + str(line[3]) + ' ' + str(line[4]) + '\n')
# Out:
#   0%|          | 1/6481 [00:00<21:19,  5.07it/s]
# syn_06056 1040 1920
# 0.42265625 0.3403846153846154 0.1203125 0.24615384615384617
# 0.26197916666666665 0.56875 0.15104166666666666 0.28557692307692306
# syn_06048 1040 1920
# 0.6427083333333333 0.39326923076923076 0.15208333333333332 0.28076923076923077
# 0.4239583333333333 0.3014423076923077 0.14895833333333333 0.30673076923076925
# 0.24270833333333333 0.3894230769230769 0.14375 0.3153846153846154
# syn_06055 1040 1920
#   0%|          | 5/6481 [00:00<11:23,  9.48it/s]
# 0.6197916666666666 0.32259615384615387 0.153125 0.24519230769230768
# 0.42473958333333334 0.2826923076923077 0.14635416666666667 0.2865384615384615
# 0.24973958333333332 0.3975961538461538 0.13489583333333333 0.2875
# syn_06078 1040 1920
# 0.6088541666666667 0.3485576923076923 0.14895833333333333 0.2798076923076923
# 0.44166666666666665 0.4653846153846154 0.128125 0.25961538461538464
# 0.2578125 0.6235576923076923 0.14895833333333333 0.30096153846153845
# ...

# %%
#기존데이터이동
anot_folder_list = glob.glob('/content/drive/MyDrive/pretrain/*.txt')

# # move
for i in tqdm(anot_folder_list):
  shutil.move(i, '/content/drive/MyDrive/pretrain_txt/')
# Out:
# 100%|██████████| 6481/6481 [01:32<00:00, 70.39it/s]

# %%
#이미지데이터이동
anot_folder_list = glob.glob('/content/drive/MyDrive/pretrain/*.png')

# # move
for i in tqdm(anot_folder_list):
  shutil.move(i, '/content/drive/MyDrive/Daycon/Image')
# Out:
# 100%|██████████| 6481/6481 [00:20<00:00, 322.00it/s]

# %%
pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#input에있는 image, yololabel을 input_copy로 tain, val, test 로 나눠서 옮기기( 이후 input_copy를 Daycon 으로 이름 변경 )
import splitfolders
input_folder = '/content/drive/MyDrive/input'
output_folder = '/content/drive/MyDrive/input_copy'
splitfolders.ratio(input_folder, output=output_folder, seed=970, ratio=(.7, .2, .1), group_prefix = 1)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Copying files: 6668 files [01:58, 23.55 files/s]
#
#
# Copying files: 6672 files [01:58, 26.21 files/s]
#
#
# Copying files: 6676 files [01:58, 28.05 files/s]
#
#
# Copying files: 6680 files [01:58, 30.50 files/s]
#
#
# Copying files: 6684 files [01:58, 32.56 files/s]
#
#
# Copying files: 6688 files [01:58, 29.59 files/s]
#
#
# Copying files: 6692 files [01:58, 30.67 files/s]
#
#
# Copying files: 6696 files [01:59, 29.25 files/s]
#
#
# Copying files: 6700 files [01:59, 26.67 files/s]
#
#
# Copying files: 6704 files [01:59, 28.35 files/s]
#
#
# Copying files: 6707 files [01:59, 26.54 files/s]
#
#
# Copying files: 6710 files [01:59, 26.17 files/s]
#
#
# Copying files: 6715 files [01:59, 30.22 files/s]
#
#
# Copying files: 6719 files [01:59, 29.32 files/s]
#
#
# Copying files: 6722 files [01:59, 28.81 files/s]
#
#
# Copying files: 6725 files [02:00, 28.15 files/s]
#
#
# Copying files: 6728 files [02:00, 23.98 files/s]
#
#
# ...

# %%
# 클래스 이름 리스트 생성
with open('/content/drive/MyDrive/classes.txt', 'r') as f:
    lines = f.readlines()
    # Extract class names and store them in a list
    classes = [line.strip().split(',')[1] for line in lines]

# %%
root_dir  = "/content/drive/MyDrive/Daycon"

# %%
#파일이름 리스트 모으기
test = glob.glob('/content/drive/MyDrive/Daycon/test/image/*')

valid = glob.glob('/content/drive/MyDrive/Daycon/valid/image/*')

train = glob.glob('/content/drive/MyDrive/Daycon/train/image/*')
# Out:
# ['/content/drive/MyDrive/Daycon/test/image/syn_00020.png', '/content/drive/MyDrive/Daycon/test/image/syn_00000.png', '/content/drive/MyDrive/Daycon/test/image/syn_00004.png', '/content/drive/MyDrive/Daycon/test/image/syn_00034.png', '/content/drive/MyDrive/Daycon/test/image/syn_00019.png', '/content/drive/MyDrive/Daycon/test/image/syn_00013.png', '/content/drive/MyDrive/Daycon/test/image/syn_00072.png', '/content/drive/MyDrive/Daycon/test/image/syn_00052.png', '/content/drive/MyDrive/Daycon/test/image/syn_00062.png', '/content/drive/MyDrive/Daycon/test/image/syn_00189.png', '/content/drive/MyDrive/Daycon/test/image/syn_00155.png', '/content/drive/MyDrive/Daycon/test/image/syn_00200.png', '/content/drive/MyDrive/Daycon/test/image/syn_00151.png', '/content/drive/MyDrive/Daycon/test/image/syn_00172.png', '/content/drive/MyDrive/Daycon/test/image/syn_00161.png', '/content/drive/MyDrive/Daycon/test/image/syn_00169.png', '/content/drive/MyDrive/Daycon/test/image/syn_00208.png', '/content/d
# ...

# %%
import yaml

yaml_data = {'nc': len(classes),
             'names': classes,
             "path": root_dir,
             "train":'/content/drive/MyDrive/Daycon/train/images', # train 경로
             "val":'/content/drive/MyDrive/Daycon/val/images', # valid 경로
             "test":'/content/drive/MyDrive/Daycon/test/images' # test 경로
             }

with open(os.path.join(root_dir, "custom.yaml"), "w") as f:
  yaml.dump(yaml_data, f)

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15705, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 15705 (delta 9), reused 23 (delta 6), pack-reused 15672
# Receiving objects: 100% (15705/15705), 14.50 MiB | 27.25 MiB/s, done.
# Resolving deltas: 100% (10754/10754), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.4/589.4 kB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 22.1 MB/s eta 0:00:00

# %%
# %%time
# %cd /content/yolov5
# !python train.py --batch 32 --epochs 25 --data '/content/drive/MyDrive/Daycon/custom.yaml' --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name car_yolov5s_resultsplzz
# Out:
# /content/yolov5
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=/content/drive/MyDrive/Daycon/custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=car_yolov5s_resultsplzz, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
